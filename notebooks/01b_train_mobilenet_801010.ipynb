# %%
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.layers import (
    Dense,
    GlobalMaxPooling2D,
    Dropout,
    BatchNormalization,
)
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix

current_dir = os.getcwd()
if current_dir.endswith("notebooks"):
    os.chdir("..")

# ARAH KE DATA 80:10:10
TRAIN_DIR = os.path.join("data", "patches (80-10-10)", "train")
VAL_DIR = os.path.join("data", "patches (80-10-10)", "val")
TEST_DIR = os.path.join("data", "patches (80-10-10)", "test")

IMG_SIZE = 224
BATCH_SIZE = 16
NUM_CLASSES = 10

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    brightness_range=[0.8, 1.2],
    rotation_range=5,
)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
)
val_generator = val_datagen.flow_from_directory(
    VAL_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
)
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    shuffle=False,
)

class_weights = compute_class_weight(
    "balanced", classes=np.unique(train_generator.classes), y=train_generator.classes
)
class_weight_dict = dict(enumerate(class_weights))
# Out:
# Found 1837 images belonging to 10 classes.
# Found 226 images belonging to 10 classes.
# Found 237 images belonging to 10 classes.

# %%
inputs = tf.keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
base_model = MobileNetV2(
    weights="imagenet", include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False

x = base_model(inputs)
x = GlobalMaxPooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(256, activation="relu", kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
predictions = Dense(NUM_CLASSES, activation="softmax")(x)

model = Model(inputs=inputs, outputs=predictions)

print("[Tahap 1/2] Feature Extraction...")
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
history_phase1 = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator,
    class_weight=class_weight_dict,
)

print("\n[Tahap 2/2] Deep Fine-Tuning (Unfreeze 50%)...")
base_model.trainable = True
freeze_until = int(len(base_model.layers) * 0.50)
for layer in base_model.layers[:freeze_until]:
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=5e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"],
)
early_stop = EarlyStopping(
    monitor="val_loss", patience=8, restore_best_weights=True, verbose=1
)
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss", factor=0.5, patience=2, min_lr=1e-7, verbose=1
)

history_phase2 = model.fit(
    train_generator,
    epochs=30,
    validation_data=val_generator,
    callbacks=[early_stop, reduce_lr],
    class_weight=class_weight_dict,
)

os.makedirs("models", exist_ok=True)
model.save(os.path.join("models", "mobilenetv2_801010.keras"))
print("Model 80:10:10 berhasil disimpan!")
# Out:
# [Tahap 1/2] Feature Extraction...
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 97s 784ms/step - accuracy: 0.2983 - loss: 6.9071 - val_accuracy: 0.4912 - val_loss: 5.3937
# Epoch 2/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 60s 523ms/step - accuracy: 0.4763 - loss: 5.3912 - val_accuracy: 0.5664 - val_loss: 4.6758
# Epoch 3/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 55s 474ms/step - accuracy: 0.5444 - loss: 4.6136 - val_accuracy: 0.6239 - val_loss: 4.0128
# Epoch 4/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 55s 478ms/step - accuracy: 0.5939 - loss: 3.9662 - val_accuracy: 0.6549 - val_loss: 3.5692
# Epoch 5/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 59s 509ms/step - accuracy: 0.6075 - loss: 3.4855 - val_accuracy: 0.7080 - val_loss: 3.0942
# Epoch 6/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 57s 492ms/step - accuracy: 0.6298 - loss: 3.0923 - val_accuracy: 0.7035 - val_loss: 2.7703
# Epoch 7/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 59s 511ms/step - accuracy: 0.6478 - loss: 2.7869 - val_accuracy: 0.7434 - val_loss: 2.5185
# Epoch 8/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 56s 484ms/step - accuracy: 0.6424 - loss: 2.5254 - val_accuracy: 0.7035 - val_loss: 2.3714
# Epoch 9/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 56s 488ms/step - accuracy: 0.6843 - loss: 2.2921 - val_accuracy: 0.6947 - val_loss: 2.2028
# Epoch 10/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 59s 510ms/step - accuracy: 0.6794 - loss: 2.1563 - val_accuracy: 0.6726 - val_loss: 2.0539
#
# [Tahap 2/2] Deep Fine-Tuning (Unfreeze 50%)...
# Epoch 1/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 118s 844ms/step - accuracy: 0.4017 - loss: 2.9377 - val_accuracy: 0.4292 - val_loss: 2.6662 - learning_rate: 5.0000e-05
# Epoch 2/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 95s 822ms/step - accuracy: 0.6451 - loss: 2.1341 - val_accuracy: 0.3982 - val_loss: 3.3382 - learning_rate: 5.0000e-05
# Epoch 3/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.7508 - loss: 1.8405
# Epoch 3: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 101s 877ms/step - accuracy: 0.7670 - loss: 1.7775 - val_accuracy: 0.4115 - val_loss: 3.0458 - learning_rate: 5.0000e-05
# Epoch 4/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 102s 885ms/step - accuracy: 0.8590 - loss: 1.5727 - val_accuracy: 0.4425 - val_loss: 2.7623 - learning_rate: 2.5000e-05
# Epoch 5/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 102s 880ms/step - accuracy: 0.8748 - loss: 1.4897 - val_accuracy: 0.4735 - val_loss: 2.5304 - learning_rate: 2.5000e-05
# Epoch 6/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 100s 867ms/step - accuracy: 0.9042 - loss: 1.3991 - val_accuracy: 0.5310 - val_loss: 2.3606 - learning_rate: 2.5000e-05
# Epoch 7/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 99s 857ms/step - accuracy: 0.9325 - loss: 1.3312 - val_accuracy: 0.6416 - val_loss: 2.1256 - learning_rate: 2.5000e-05
# Epoch 8/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 97s 844ms/step - accuracy: 0.9347 - loss: 1.3035 - val_accuracy: 0.7124 - val_loss: 1.7900 - learning_rate: 2.5000e-05
# Epoch 9/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 99s 859ms/step - accuracy: 0.9559 - loss: 1.2318 - val_accuracy: 0.7611 - val_loss: 1.7156 - learning_rate: 2.5000e-05
# Epoch 10/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 97s 840ms/step - accuracy: 0.9581 - loss: 1.1969 - val_accuracy: 0.8938 - val_loss: 1.4245 - learning_rate: 2.5000e-05
# Epoch 11/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 98s 847ms/step - accuracy: 0.9733 - loss: 1.1620 - val_accuracy: 0.8982 - val_loss: 1.3720 - learning_rate: 2.5000e-05
# Epoch 12/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 98s 850ms/step - accuracy: 0.9701 - loss: 1.1426 - val_accuracy: 0.9381 - val_loss: 1.3005 - learning_rate: 2.5000e-05
# Epoch 13/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 94s 811ms/step - accuracy: 0.9831 - loss: 1.0951 - val_accuracy: 0.9381 - val_loss: 1.2659 - learning_rate: 2.5000e-05
# Epoch 14/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 96s 835ms/step - accuracy: 0.9858 - loss: 1.0676 - val_accuracy: 0.9513 - val_loss: 1.2059 - learning_rate: 2.5000e-05
# Epoch 15/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 712ms/step - accuracy: 0.9820 - loss: 1.0526 - val_accuracy: 0.9558 - val_loss: 1.1188 - learning_rate: 2.5000e-05
# Epoch 16/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 78s 679ms/step - accuracy: 0.9891 - loss: 1.0245 - val_accuracy: 0.9646 - val_loss: 1.0903 - learning_rate: 2.5000e-05
# Epoch 17/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 78s 680ms/step - accuracy: 0.9897 - loss: 0.9994 - val_accuracy: 0.9690 - val_loss: 1.0467 - learning_rate: 2.5000e-05
# Epoch 18/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 79s 685ms/step - accuracy: 0.9962 - loss: 0.9696 - val_accuracy: 0.9690 - val_loss: 1.0282 - learning_rate: 2.5000e-05
# Epoch 19/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 78s 680ms/step - accuracy: 0.9929 - loss: 0.9556 - val_accuracy: 0.9735 - val_loss: 0.9787 - learning_rate: 2.5000e-05
# Epoch 20/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 78s 680ms/step - accuracy: 0.9929 - loss: 0.9327 - val_accuracy: 0.9690 - val_loss: 0.9560 - learning_rate: 2.5000e-05
# Epoch 21/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 80s 691ms/step - accuracy: 0.9929 - loss: 0.9103 - val_accuracy: 0.9823 - val_loss: 0.9247 - learning_rate: 2.5000e-05
# Epoch 22/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 711ms/step - accuracy: 0.9935 - loss: 0.8846 - val_accuracy: 0.9735 - val_loss: 0.9117 - learning_rate: 2.5000e-05
# Epoch 23/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 713ms/step - accuracy: 0.9935 - loss: 0.8633 - val_accuracy: 0.9779 - val_loss: 0.8795 - learning_rate: 2.5000e-05
# Epoch 24/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 711ms/step - accuracy: 0.9929 - loss: 0.8399 - val_accuracy: 0.9823 - val_loss: 0.8477 - learning_rate: 2.5000e-05
# Epoch 25/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 713ms/step - accuracy: 0.9956 - loss: 0.8139 - val_accuracy: 0.9735 - val_loss: 0.8476 - learning_rate: 2.5000e-05
# Epoch 26/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 711ms/step - accuracy: 0.9962 - loss: 0.7893 - val_accuracy: 0.9779 - val_loss: 0.8186 - learning_rate: 2.5000e-05
# Epoch 27/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 711ms/step - accuracy: 0.9978 - loss: 0.7626 - val_accuracy: 0.9779 - val_loss: 0.7836 - learning_rate: 2.5000e-05
# Epoch 28/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 711ms/step - accuracy: 0.9951 - loss: 0.7444 - val_accuracy: 0.9823 - val_loss: 0.7494 - learning_rate: 2.5000e-05
# Epoch 29/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 713ms/step - accuracy: 0.9973 - loss: 0.7173 - val_accuracy: 0.9779 - val_loss: 0.7241 - learning_rate: 2.5000e-05
# Epoch 30/30
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 82s 710ms/step - accuracy: 0.9978 - loss: 0.6873 - val_accuracy: 0.9823 - val_loss: 0.7058 - learning_rate: 2.5000e-05
# Restoring model weights from the end of the best epoch: 30.
# Model 80:10:10 berhasil disimpan!

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f"\nAkurasi Test Set (80:10:10): {test_acc * 100:.2f}%\n")

predictions = model.predict(test_generator)
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes
class_names = list(test_generator.class_indices.keys())

print(classification_report(y_true, y_pred, target_names=class_names))

os.makedirs("reports", exist_ok=True)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=class_names,
    yticklabels=class_names,
)
plt.title("Confusion Matrix - MobileNetV2 (80:10:10)")
plt.ylabel("Label Asli")
plt.xlabel("Label Prediksi")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.savefig(os.path.join("reports", "cm_mobilenet_801010.png"))
plt.show()

# Learning Curves
acc = history_phase1.history["accuracy"] + history_phase2.history["accuracy"]
val_acc = (
    history_phase1.history["val_accuracy"] + history_phase2.history["val_accuracy"]
)
loss = history_phase1.history["loss"] + history_phase2.history["loss"]
val_loss = history_phase1.history["val_loss"] + history_phase2.history["val_loss"]
initial_epochs = len(history_phase1.history["accuracy"])
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label="Akurasi Latih")
plt.plot(epochs_range, val_acc, label="Akurasi Validasi")
plt.axvline(x=initial_epochs, color="green", linestyle="--", label="Mulai Fine-Tuning")
plt.title("Kurva Akurasi (80:10:10)")
plt.legend(loc="lower right")
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label="Loss Latih")
plt.plot(epochs_range, val_loss, label="Loss Validasi")
plt.axvline(x=initial_epochs, color="green", linestyle="--", label="Mulai Fine-Tuning")
plt.title("Kurva Loss (80:10:10)")
plt.legend(loc="upper right")
plt.grid(True)

plt.savefig(os.path.join("reports", "lc_mobilenet_801010.png"))
plt.show()
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 414ms/step - accuracy: 0.9873 - loss: 0.6940
#
# Akurasi Test Set (80:10:10): 98.73%
#
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 378ms/step
#                        precision    recall  f1-score   support
#
#                   151       1.00      1.00      1.00        22
#       destined-rivals       1.00      0.96      0.98        25
#        evolving-skies       1.00      0.96      0.98        24
#      journey-together       0.95      1.00      0.97        19
#           lost-origin       0.96      1.00      0.98        26
#        paldea-evolved       0.97      1.00      0.98        29
#         paldean-fates       1.00      1.00      1.00        25
#  prismatic-evolutions       1.00      0.94      0.97        18
# scarlet-violet-promos       1.00      1.00      1.00        23
#        surging-sparks       1.00      1.00      1.00        26
#
#              accuracy                           0.99       237
#             macro avg       0.99      0.99      0.99       237
#          weighted avg       0.99      0.99      0.99       237
